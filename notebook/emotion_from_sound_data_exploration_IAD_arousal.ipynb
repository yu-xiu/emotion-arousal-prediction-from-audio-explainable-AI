# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Load Dataset

# %%
IAD_file_path = '/content/drive/MyDrive/IADSED-2.csv'

IAD_df = pd.read_csv(IAD_file_path) #loading IAD data

# %%
IAD_df.shape
# Out:
# (935, 76)

# %% [markdown]
# #Clean Dataset

# %%
# check if IAD has null rows
iad_null_rows = IAD_df[IAD_df.isnull().any(axis=1)]
# print(null_rows)

# %%
# drop null from IAD
IAD_df = IAD_df.dropna()
# emo_df = emo_df.dropna()

# %%
IAD_df.head(3)
# Out:
#      source         description      category fname BE_Classification  \
# 0  Expanded        LightMusic24         Music     1                 H
# 1  Expanded             Sci-Fi4  Sound Effect     2                 F
# 2  Expanded  Suspense Thriller1  Sound Effect     3                FS
#
#     arousal   valence  dominance  dynamics_rms_mean  dynamics_rms_std  ...  \
# 0  4.181818  6.545455       5.73           0.095067          0.042815  ...
# 1  6.181818  3.227273       3.55           0.077893          0.039497  ...
# 2  5.227273  4.227273       4.23           0.069022          0.038171  ...
#
#    timbre_lowenergy_std  timbre_spectralflux_mean  timbre_spectralflux_std  \
# 0              1.422069                 48.254947                24.727503
# 1              2.560911                 71.886219                35.961220
# 2              2.168929                 49.664474                28.268124
#
#    pitch_pitch_mean  tonal_keyclarity_mean  tonal_keyclarity_std  \
# ...

# %%
IAD_df_cp = IAD_df.copy()

# %%
IAD_df_cp.shape
# Out:
# (927, 76)

# %%
IAD_df.shape
# Out:
# (927, 76)

# %%
IAD_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 927 entries, 0 to 934
# Data columns (total 76 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   source                             927 non-null    object
#  1   description                        927 non-null    object
#  2   category                           927 non-null    object
#  3   fname                              927 non-null    object
#  4   BE_Classification                  927 non-null    object
#  5   arousal                            927 non-null    float64
#  6   valence                            927 non-null    float64
#  7   dominance                          927 non-null    float64
#  8   dynamics_rms_mean                  927 non-null    float64
#  9   dynamics_rms_std                   927 non-null    float64
#  10  rhythm_attacktime_mean             927 non-null    float64
# ...

# %%
IAD_df.describe()
# Out:
#           arousal     valence   dominance  dynamics_rms_mean  \
# count  927.000000  927.000000  927.000000         927.000000
# mean     5.586514    4.546923    4.861435           0.100988
# std      1.174768    1.421621    0.971991           0.072109
# min      1.909091    1.181818    2.000000           0.005409
# 25%      4.818182    3.545455    4.180000           0.051975
# 50%      5.681818    4.375000    4.910000           0.085427
# 75%      6.409091    5.541667    5.590000           0.130013
# max      8.458333    8.090909    7.240000           0.734465
#
#        dynamics_rms_std  rhythm_attacktime_mean  rhythm_tempo_mean  \
# count        927.000000              927.000000         927.000000
# mean           0.064742                0.033220         123.089600
# std            0.046669                0.035635          28.897076
# min            0.003401                0.006360          47.802704
# 25%            0.034328                0.016981         103.546228
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## correlation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_top_correlations(df, target_col, top_n=10):
    """
    Plot a bar chart of the top N features most correlated with the target column.

    Parameters:
    - df: pandas.DataFrame
        The input DataFrame containing both features and the target variable.
    - target_col: str
        The name of the target column in `df`.
    - top_n: int, optional (default=10)
        The number of top features (based on absolute correlation) to display in the plot.

    Returns:
    - None. Displays a matplotlib bar plot showing the top correlated features.
    """
    corr = df.corr()[target_col].drop(target_col).abs().sort_values(ascending=False).head(top_n)
    plt.figure(figsize=(50, 3))
    sns.barplot(x=corr.values, y=corr.index)
    plt.title(f"Top {top_n} features correlated with {target_col}")
    plt.xlabel("Absolute Correlation")
    plt.ylabel("Feature")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Heatmap

# %%
def plot_target_feature_heatmap(df, target_col, corr_threshold=0.3):
    """
    Plot the heatmap for target and features with correlation threshold of 0.3.

    Parameters:
    - df: pandas.DataFrame
        The input DataFrame containing both features and the target variable.
    - target_col: str
        The name of the target column in `df`.
    - corr_threshold: float, optional (default=0.3)
        Correlation threshold with 0.3.

    Returns:
    - None. Displays the heatmap
    """
    corr_with_target = df.corr()[target_col].abs()
    selected = corr_with_target[corr_with_target > corr_threshold].index.tolist()
    selected = [col for col in selected if col != target_col]
    selected_df = df[selected]
    corr_matrix = selected_df.corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
    plt.title(f"Correlation Heatmap of Top Features for {target_col}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## readuce redandacny
# redandancy can confues model
# reduce the highly correlated features
# reduce computation cost

# %%
import numpy as np
def select_target_related_features(df, target_col, corr_threshold=0.3):
    """
    Parameters:
    - df: pandas DataFrame
      The input DataFrame containing both features and the target variable.
    - target_col: str
      The name of the target column in `df` with which to compute correlations
    - corr_threshold: float digit, optional (default = 0.3)
      The minimum absolute correlation value required for a feature to be selected
    Returns:
    - List of column names (features) that have a correlation greater than `corr_threshold`
      (in absolute value) with the target column
    """
    corr_with_target = df.corr()[target_col].abs().sort_values(ascending=False)
    selected = corr_with_target[corr_with_target > corr_threshold].index.tolist()
    if target_col in selected:
        selected.remove(target_col)
    return selected

# %%
def remove_redundant_features(df, selected_features, redundancy_threshold=0.8):
    """
    Remove redundant features from a list of selected features based on their pairwise correlation.

    Parameters:
    - df: pandas.DataFrame
        The input DataFrame containing the feature columns.
    - selected_features: list of str
        A list of feature column names to evaluate for redundancy.
    - redundancy_threshold: float, optional (default=0.8)
        The absolute correlation threshold above which two features are considered redundant.
        If the correlation between two features exceeds this threshold, one of them will be removed.

    Returns:
    - List of feature names with redundant features removed based on the specified threshold.
    """

    sub_df = df[selected_features]
    corr_matrix = sub_df.corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > redundancy_threshold)]
    return sub_df.drop(columns=to_drop), to_drop

# %% [markdown]
# ## Plot the relationship between a single feature and the target variable using a scatter plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_feature_vs_target(df, feature_col, target_col, figsize=(8, 5), color='blue', add_reg_line=False):
    """
    Parameters:
    - df: pandas DataFrame
    - feature_col: str, feature name (x)
    - target_col: str, target (y)
    - figsize: tuple, image size
    - color: str, color of points
    - add_reg_line: bool, linear regression line
    """
    plt.figure(figsize=figsize)

    if add_reg_line:
        sns.regplot(data=df, x=feature_col, y=target_col, scatter_kws={"s": 15, "alpha": 0.6}, line_kws={"color": "red"})
    else:
        plt.scatter(df[feature_col], df[target_col], color=color, s=15, alpha=0.6)

    plt.xlabel(feature_col)
    plt.ylabel(target_col)
    plt.title(f'{feature_col} vs {target_col}')
    plt.grid(True, linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
import joblib

def plot_top_correlated_features(df, target_col, top_n=6, save_path=None):
    corr = df.corr()[target_col].drop(target_col).sort_values(key=abs, ascending=False)
    top_features = corr.head(top_n).index.tolist()

    # plot
    for feat in top_features:
        plot_feature_vs_target(df, feat, target_col, add_reg_line=True)

    # save top features
    if save_path is not None:
        joblib.dump(top_features, save_path)
        print(f"✅ Top {top_n} features saved to {save_path}")

    return top_features

# %% [markdown]
# ## visualizing IAD dataset

# %% [markdown]
# ## IAD arousal <-> features correlation visualization and analysis

# %%
IAD_columns_to_drop = ["source", "description", "category", 'fname', 'BE_Classification'] #dropping the cols that are not used in the correlation plotting
IAD_with_features_df = IAD_df_cp.drop(columns=IAD_columns_to_drop)

# %%
IAD_with_features_df.shape
# Out:
# (927, 71)

# %%
IAD_with_features_df.to_csv('/content/drive/MyDrive/emotion_from_sound_AI_project/cleaned_data/cleaned_IAD_full_features.csv', index=False)

# %%
plot_top_correlations(IAD_with_features_df, "arousal")

# %% [markdown]
# ### Analysis
# correlation of arousal and valence is around 0.4.
#
# This means that higher arousal tends to be associated with more positive emotions, but the trend is not strict.
#
# Arousal: how "intense" an emotion is (calm vs. excited)
# Valence: how "positive or negative" an emotion is (sad vs. happy)
#
# correlation of arousal and dominance is around 0.51.
#
# This is moderate to strong positive correlation.
#
# as arousal increases, dominance tends to increase.
#
# people who feel more aroused (e.g., excited, intense) also tend to feel more dominant (in control, powerful) — but not always.

# %%
plot_target_feature_heatmap(IAD_with_features_df, "arousal")

# %%
# select strong related features to arousal target
target_col = "arousal"
selected_arousal_features = select_target_related_features(IAD_with_features_df, target_col, corr_threshold=0.3)
print(selected_arousal_features)

# drop high similer features from the selected features
final_df, dropped_features_for_arousal = remove_redundant_features(IAD_with_features_df, selected_arousal_features, redundancy_threshold=0.9)

print(dropped_features_for_arousal)
# Out:
# ['timbre_spectralflux_mean', 'dominance', 'timbre_spectralflux_std', 'dynamics_rms_mean', 'valence', 'dynamics_rms_std', 'spectral_roughness_mean', 'spectral_spectentropy_mean', 'spectral_skewness_mean']
# []

# %%
save_path = "/content/drive/MyDrive/emotion_from_sound_AI_project/features/top10_IAD_arousal_features.pkl"

top_features = plot_top_correlated_features(
    IAD_with_features_df,
    target_col="arousal",
    top_n=10,
    save_path=save_path
)
# Out:
# ✅ Top 10 features saved to /content/drive/MyDrive/emotion_from_sound_AI_project/features/top10_IAD_arousal_features.pkl

# %%
print(top_features)
# Out:
# ['timbre_spectralflux_mean', 'dominance', 'timbre_spectralflux_std', 'dynamics_rms_mean', 'valence', 'dynamics_rms_std', 'spectral_roughness_mean', 'spectral_spectentropy_mean', 'spectral_skewness_mean', 'spectral_kurtosis_mean']

# %% [markdown]
# # Analysis
# Based on exploratory analysis—including correlation analysis, heatmap visualization, and scatter plots—many of the top features are highly skewed, with values densely clustered on the left side of the sample distribution and sparse on the right. This suggests that the relationship between features and the target variable may be non-linear and not uniformly distributed.
#
# To account for this, a mix of linear and non-linear regression models for comparison:
#
# Linear Regression: as a fast and interpretable baseline model.
#
# Random Forest Regressor: a tree-based ensemble model that handles non-linear relationships and skewed features without requiring feature scaling.
#
# XGBoost Regressor: a high-performance gradient boosting model known for strong predictive accuracy and robustness to feature distribution issues.
#
# MLP Regressor (Multilayer Perceptron): a neural network-based model that can capture complex patterns and feature interactions, especially after feature normalization.
